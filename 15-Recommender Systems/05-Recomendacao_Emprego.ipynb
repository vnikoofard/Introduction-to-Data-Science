# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import nltk
from google.colab import drive
import pickle
import plotly.express as px

# %%
# Para manter montada a pasta do Google Drive no COLAB
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Carregando os dados

# %% [markdown]
# ## Trabalho

# %% [markdown]
# Carregando os dados de trabalho

# %%
path1 = '/content/drive/MyDrive/Dados_Empregos/'
arquivo1 = 'Combined_Jobs_Final.csv'
df_jobs = pd.read_csv(path1 + arquivo1)
df_jobs.head()
# Out:
#    Job.ID  Provider Status                                               Slug  \
# 0     111         1   open                    palo-alto-ca-tacolicious-server
# 1     113         1   open    san-francisco-ca-claude-lane-kitchen-staff-chef
# 2     117         1   open  san-francisco-ca-machka-restaurants-corp-barte...
# 3     121         1   open                  brisbane-ca-teriyaki-house-server
# 4     127         1   open  los-angeles-ca-rosa-mexicano-sunset-kitchen-st...
#
#                                          Title            Position  \
# 0                         Server @ Tacolicious              Server
# 1             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2         Bartender @ Machka Restaurants Corp.           Bartender
# 3                      Server @ Teriyaki House              Server
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City  State.Name State.Code  ...  \
# ...

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84090 entries, 0 to 84089
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job.ID              84090 non-null  int64
#  1   Provider            84090 non-null  int64
#  2   Status              84090 non-null  object
#  3   Slug                84090 non-null  object
#  4   Title               84090 non-null  object
#  5   Position            84090 non-null  object
#  6   Company             81819 non-null  object
#  7   City                83955 non-null  object
#  8   State.Name          83919 non-null  object
#  9   State.Code          83919 non-null  object
#  10  Address             36 non-null     object
#  11  Latitude            84090 non-null  float64
#  12  Longitude           84090 non-null  float64
#  13  Industry            267 non-null    object
#  14  Job.Description     84034 non-null  object
# ...

# %% [markdown]
# #### Análise Exploratória dos Dados

# %% [markdown]
# Checando valores nulos

# %%
df_jobs.isnull().sum() #/ len(df_jobs) * 100
# Out:
# Job.ID                    0
# Provider                  0
# Status                    0
# Slug                      0
# Title                     0
# Position                  0
# Company                2271
# City                    135
# State.Name              171
# State.Code              171
# Address               84054
# Latitude                  0
# Longitude                 0
# Industry              83823
# Job.Description          56
# Requirements          84090
# Salary                83861
# Listing.Start           683
# Listing.End             167
# Employment.Type          10
# Education.Required      267
# Created.At                0
# Updated.At                0
# dtype: int64

# %% [markdown]
# Temos muitos valores nulos, vamos limpar os dados para cada coluna

# %% [markdown]
# Escolher as colunas

# %% [markdown]
# Vamos considerar apenas as colunas 'Job.ID', 'Title', 'Position', 'Company','City', 'Empl_type','Edu_req','Job_Description'

# %%
cols = ['Job.ID']+['Title']+['Position']+ ['Company']+['City']+['Employment.Type']+['Job.Description']
df_jobs =df_jobs[cols]
df_jobs.columns = ['Job.ID', 'Title', 'Position', 'Company','City', 'Empl_type','Job_Description']
df_jobs.head()
# Out:
#    Job.ID                                        Title            Position  \
# 0     111                         Server @ Tacolicious              Server
# 1     113             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2     117         Bartender @ Machka Restaurants Corp.           Bartender
# 3     121                      Server @ Teriyaki House              Server
# 4     127  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City  Empl_type  \
# 0               Tacolicious      Palo Alto  Part-Time
# 1               Claude Lane  San Francisco  Part-Time
# 2  Machka Restaurants Corp.  San Francisco  Part-Time
# 3            Teriyaki House       Brisbane  Part-Time
# 4    Rosa Mexicano - Sunset    Los Angeles  Part-Time
#
#                                      Job_Description
# 0  Tacolicious' first Palo Alto store just opened...
# 1   \r\n\r\nNew French Brasserie in S.F. Financia...
# ...

# %%
# Checando novamente valores nulos
df_jobs.isnull().sum() #/ len(df_jobs) * 100
# Out:
# Job.ID                0
# Title                 0
# Position              0
# Company            2271
# City                135
# Empl_type            10
# Job_Description      56
# dtype: int64

# %% [markdown]
# Obtendo os registros nulos da coluna 'City'

# %%
df_nan_city = df_jobs[pd.isnull(df_jobs['City'])]
df_nan_city.groupby(['Company'])['City'].count()
# Out:
# Company
# Academic Year In America                0
# CBS Healthcare Services and Staffing    0
# CHI Payment Systems                     0
# Driveline Retail                        0
# Educational Testing Services            0
# Genesis Health System                   0
# Genesis Health Systems                  0
# Home Instead Senior Care                0
# St. Francis Hospital                    0
# Volvo Group                             0
# Name: City, dtype: int64

# %% [markdown]
# Nós vemos que há 10 empresas que têm valores NaN, então deve ser adicionado manualmente suas sedes (simplesmente pesquisando no google)

# %%
#replacing nan with thier headquarters location
df_jobs['Company'] = df_jobs['Company'].replace(['Genesis Health Systems'], 'Genesis Health System')
df_jobs.loc[df_jobs.Company == 'CHI Payment Systems', 'City'] = 'Illinois'
df_jobs.loc[df_jobs.Company == 'Academic Year In America', 'City'] = 'Stamford'
df_jobs.loc[df_jobs.Company == 'CBS Healthcare Services and Staffing ', 'City'] = 'Urbandale'
df_jobs.loc[df_jobs.Company == 'Driveline Retail', 'City'] = 'Coppell'
df_jobs.loc[df_jobs.Company == 'Educational Testing Services', 'City'] = 'New Jersey'
df_jobs.loc[df_jobs.Company == 'Genesis Health System', 'City'] = 'Davennport'
df_jobs.loc[df_jobs.Company == 'Home Instead Senior Care', 'City'] = 'Nebraska'
df_jobs.loc[df_jobs.Company == 'St. Francis Hospital', 'City'] = 'New York'
df_jobs.loc[df_jobs.Company == 'Volvo Group', 'City'] = 'Washington'
df_jobs.loc[df_jobs.Company == 'CBS Healthcare Services and Staffing', 'City'] = 'Urbandale'

# %%
df_jobs.isnull().sum()
# Out:
# Job.ID                0
# Title                 0
# Position              0
# Company            2271
# City                  0
# Empl_type            10
# Job_Description      56
# dtype: int64

# %%
df_jobs['Empl_type'].unique()
# Out:
# array(['Part-Time', 'Full-Time/Part-Time', 'Seasonal/Temp', 'Per Diem',
#        'Intern', nan, 'Full-Time', 'Contract', 'Temporary/seasonal'],
#       dtype=object)

# %%
df_nan_emp = df_jobs[pd.isnull(df_jobs['Empl_type'])]
df_nan_emp.head()
# Out:
#        Job.ID                   Title         Position Company           City  \
# 10768  153197  Driving Partner @ Uber  Driving Partner    Uber  San Francisco
# 10769  153198  Driving Partner @ Uber  Driving Partner    Uber    Los Angeles
# 10770  153199  Driving Partner @ Uber  Driving Partner    Uber        Chicago
# 10771  153200  Driving Partner @ Uber  Driving Partner    Uber         Boston
# 10772  153201  Driving Partner @ Uber  Driving Partner    Uber      Ann Arbor
#
#       Empl_type                                    Job_Description
# 10768       NaN  Uber is changing the way the world moves. From...
# 10769       NaN  Uber is changing the way the world moves. From...
# 10770       NaN  Uber is changing the way the world moves. From...
# 10771       NaN  Uber is changing the way the world moves. From...
# 10772       NaN  Uber is changing the way the world moves. From...

# %%
df_nan_emp.groupby(['Company'])['Empl_type'].size()
# Out:
# Company
# Uber    10
# Name: Empl_type, dtype: int64

# %% [markdown]
# O tipo de emprego NAN são da Uber, então assumo que são meio período e período integral

# %%
# Preenchendo valores nulos com meio período / período integral
df_jobs['Empl_type']=df_jobs['Empl_type'].fillna('Full-Time/Part-Time')

# %%
df_jobs.isnull().sum()
# Out:
# Job.ID                0
# Title                 0
# Position              0
# Company            2271
# City                  0
# Empl_type             0
# Job_Description      56
# dtype: int64

# %% [markdown]
# Criando a coluna texto

# %% [markdown]
# Combinaremos as colunas posição, empresa, cidade, tipo de emprego e posição

# %%
df_jobs["text"] = df_jobs["Position"].map(str) + " " + df_jobs["Company"] +" "+ df_jobs["City"]+ " "+df_jobs['Empl_type']+" "+df_jobs['Job_Description'] +" "+df_jobs['Title']
df_jobs.head(2)
# Out:
#    Job.ID                             Title            Position      Company  \
# 0     111              Server @ Tacolicious              Server  Tacolicious
# 1     113  Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef  Claude Lane
#
#             City  Empl_type  \
# 0      Palo Alto  Part-Time
# 1  San Francisco  Part-Time
#
#                                      Job_Description  \
# 0  Tacolicious' first Palo Alto store just opened...
# 1   \r\n\r\nNew French Brasserie in S.F. Financia...
#
#                                                 text
# 0  Server Tacolicious Palo Alto Part-Time Tacolic...
# 1  Kitchen Staff/Chef Claude Lane San Francisco P...

# %% [markdown]
# Vamos extrair apenas o ID, texto e título do trabalho

# %%
df_all = df_jobs[['Job.ID', 'text', 'Title']]

df_all = df_all.fillna(" ")

df_all.head()
# Out:
#    Job.ID                                               text  \
# 0     111  Server Tacolicious Palo Alto Part-Time Tacolic...
# 1     113  Kitchen Staff/Chef Claude Lane San Francisco P...
# 2     117  Bartender Machka Restaurants Corp. San Francis...
# 3     121  Server Teriyaki House Brisbane Part-Time  ● Se...
# 4     127  Kitchen Staff/Chef Rosa Mexicano - Sunset Los ...
#
#                                          Title
# 0                         Server @ Tacolicious
# 1             Kitchen Staff/Chef @ Claude Lane
# 2         Bartender @ Machka Restaurants Corp.
# 3                      Server @ Teriyaki House
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset

# %% [markdown]
# Temos 84090 registros e 3 colunas

# %%
df_all.shape
# Out:
# (84090, 3)

# %%
df_all.isnull().sum()
# Out:
# Job.ID    0
# text      0
# Title     0
# dtype: int64

# %% [markdown]
# Vamos baixar da biblioteca nltk os pacotes:
# - punkt: responsável por tokenizar as palavras
# - stopwords: responsável por remover as palavras que não agregam valor ao texto
# - wordnet: responsável por lematizar as palavras
# - averaged_perceptron_tagger: responsável por classificar as palavras em substantivos, verbos, adjetivos, etc

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# Vamos importar os pacotes baixados e criar duas funções:
# - black_txt: responsável por remover as palavras que não agregam valor ao texto
# - clean_txt: responsável por lematizar as palavras

# %%
from nltk.corpus import stopwords
import re
import string
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
stop = stopwords.words('english')
stop_words_ = set(stopwords.words('english'))
wn = WordNetLemmatizer()

def black_txt(token):
    return  token not in stop_words_ and token not in list(string.punctuation)  and len(token)>2

def clean_txt(text):
  clean_text = []
  clean_text2 = []
  text = re.sub("'", "",text)
  text=re.sub("(\\d|\\W)+"," ",text)
  text = text.replace("nbsp", "")
  clean_text = [ wn.lemmatize(word, pos="v") for word in word_tokenize(text.lower()) if black_txt(word)]
  clean_text2 = [word for word in clean_text if black_txt(word)]
  return " ".join(clean_text2)

# %% [markdown]
# Limpando o texto

# %%
df_all['text'] = df_all['text'].apply(clean_txt)

# %% [markdown]
# Finalmente nós temos o texto limpo

# %%
df_all.head()
# Out:
#    Job.ID                                               text  \
# 0     111  server tacolicious palo alto part time tacolic...
# 1     113  kitchen staff chef claude lane san francisco p...
# 2     117  bartender machka restaurants corp san francisc...
# 3     121  server teriyaki house brisbane part time serve...
# 4     127  kitchen staff chef rosa mexicano sunset los an...
#
#                                          Title
# 0                         Server @ Tacolicious
# 1             Kitchen Staff/Chef @ Claude Lane
# 2         Bartender @ Machka Restaurants Corp.
# 3                      Server @ Teriyaki House
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset

# %% [markdown]
# ### Dados usuários
# Vamos pegar o dataset de trabalhos visualizados

# %% [markdown]
# #### Dados históricos dos usuários

# %%
arquivo2 = 'Job_Views.csv'
df_job_view = pd.read_csv(path1 + arquivo2)
df_job_view.head()
# Out:
#    Applicant.ID  Job.ID                                              Title  \
# 0         10000   73666              Cashiers & Valets Needed! @ WallyPark
# 1         10000   96655  Macy's Seasonal Retail Fragrance Cashier  - Ga...
# 2         10001   84141  Part Time Showroom Sales / Cashier @ Grizzly I...
# 3         10002   77989  Event Specialist Part Time @ Advantage Sales &...
# 4         10002   69568          Bonefish - Kitchen Staff @ Bonefish Grill
#
#                                             Position  \
# 0                          Cashiers & Valets Needed!
# 1  Macy's Seasonal Retail Fragrance Cashier  - Ga...
# 2                 Part Time Showroom Sales / Cashier
# 3                         Event Specialist Part Time
# 4                           Bonefish - Kitchen Staff
#
#                        Company          City      State.Name State.Code  \
# 0                    WallyPark        Newark      New Jersey         NJ
# ...

# %% [markdown]
# Nesse caso usaremos apenas as colunas 'Applicant.ID', 'Job.ID', 'Position', 'Company','City'

# %%
df_job_view = df_job_view[['Applicant.ID', 'Job.ID', 'Position', 'Company','City']]
df_job_view["select_pos_com_city"] = df_job_view["Position"].map(str) + "  " + df_job_view["Company"] +"  "+ df_job_view["City"]
df_job_view['select_pos_com_city'] = df_job_view['select_pos_com_city'].map(str).apply(clean_txt)
df_job_view['select_pos_com_city'] = df_job_view['select_pos_com_city'].str.lower()
df_job_view = df_job_view[['Applicant.ID','select_pos_com_city']]
df_job_view.head()
# Out:
#    Applicant.ID                                select_pos_com_city
# 0         10000                cashier valet need wallypark newark
# 1         10000  macys seasonal retail fragrance cashier garden...
# 2         10001  part time showroom sales cashier grizzly indus...
# 3         10002  event specialist part time advantage sales mar...
# 4         10002   bonefish kitchen staff bonefish grill greenville

# %% [markdown]
# #### Dataset de experiência dos usuários

# %%
arquivo3 = 'Experience.csv'
df_experience = pd.read_csv(path1 + arquivo3)
df_experience.head()
# Out:
#    Applicant.ID                                      Position.Name  \
# 0         10001  Account Manager / Sales Administration / Quali...
# 1         10001    Electronics Technician / Item Master Controller
# 2         10001                                   Machine Operator
# 3         10003                             maintenance technician
# 4         10003                                 Electrical Helper
#
#                Employer.Name         City            State.Name State.Code  \
# 0         Barcode Resourcing   Bellingham            Washington         WA
# 1                Ryzex Group   Bellingham            Washington         WA
# 2                comptec inc       Custer            Washington         WA
# 3           Winn residental    washington  District of Columbia         DC
# 4  michael and son services   alexandria               Virginia         VA
#
#    Start.Date    End.Date                                    Job.Description  \
# ...

# %% [markdown]
# Vamos aplicar a limpeza do texto dos dados

# %%
df_experience= df_experience[['Applicant.ID','Position.Name']]
df_experience['Position.Name'] = df_experience['Position.Name'].map(str).apply(clean_txt)
df_experience.head()
# Out:
#    Applicant.ID                                      Position.Name
# 0         10001  account manager sales administration quality a...
# 1         10001      electronics technician item master controller
# 2         10001                                   machine operator
# 3         10003                             maintenance technician
# 4         10003                                  electrical helper

# %%
df_experience =  df_experience.sort_values(by='Applicant.ID')
df_experience = df_experience.fillna(" ")
df_experience.head()
# Out:
#       Applicant.ID      Position.Name
# 2763             2          volunteer
# 2762             2  writer uloop blog
# 3759             3      market intern
# 3758             3             server
# 3757             3          prep cook

# %% [markdown]
# O mesmo candidato tem 3 candidaturas 100001 em uma única linha, então precisamos juntá-los

# %%
df_experience = df_experience.groupby('Applicant.ID', sort=False)['Position.Name'].apply(' '.join).reset_index()
df_experience.head(5)
# Out:
#    Applicant.ID                                    Position.Name
# 0             2                      volunteer writer uloop blog
# 1             3                   market intern server prep cook
# 2             6                                project assistant
# 3             8  deli clerk server cashier food prep order taker
# 4            11                                          cashier

# %% [markdown]
# #### Dataset de cargo de interesse

# %%
arquivo4 = 'Positions_Of_Interest.csv'
df_poi = pd.read_csv(path1 + arquivo4)
df_poi = df_poi.sort_values(by='Applicant.ID')
df_poi.head()
# Out:
#       Applicant.ID Position.Of.Interest               Created.At  \
# 6437            96               Server  2014-08-14 15:56:42 UTC
# 1156           153              Barista  2014-08-14 15:56:43 UTC
# 1155           153                 Host  2014-08-14 15:56:42 UTC
# 1154           153               Server  2014-08-14 15:56:42 UTC
# 1158           153            Sales Rep  2014-08-14 15:56:47 UTC
#
#                    Updated.At
# 6437  2015-02-26 20:35:12 UTC
# 1156  2015-02-18 02:35:06 UTC
# 1155  2015-02-26 20:35:12 UTC
# 1154  2015-02-26 20:35:12 UTC
# 1158  2015-03-02 02:13:08 UTC

# %%
df_poi = df_poi.drop(['Updated.At', 'Created.At'], axis=1)


#limpando os dados
df_poi['Position.Of.Interest']=df_poi['Position.Of.Interest'].map(str).apply(clean_txt)
df_poi = df_poi.fillna(" ")
df_poi.head(10)
# Out:
#       Applicant.ID  Position.Of.Interest
# 6437            96                server
# 1156           153               barista
# 1155           153                  host
# 1154           153                server
# 1158           153             sales rep
# 1157           153  customer service rep
# 1952           256                  host
# 1957           256       production area
# 1956           256             sales rep
# 1955           256  customer service rep

# %%
df_poi = df_poi.groupby('Applicant.ID', sort=True)['Position.Of.Interest'].apply(' '.join).reset_index()
df_poi.head()
# Out:
#    Applicant.ID                               Position.Of.Interest
# 0            96                                             server
# 1           153  barista host server sales rep customer service...
# 2           256  host production area sales rep customer servic...
# 3           438           customer service rep barista host server
# 4           568      receptionist customer service rep book keeper

# %% [markdown]
# ####  Junção dos três

# %% [markdown]
# Mesclando os datasets de trabalhos e experiência

# %%
df_jobs_exp = df_job_view.merge(df_experience, left_on='Applicant.ID', right_on='Applicant.ID', how='outer')
df_jobs_exp = df_jobs_exp.fillna(' ')
df_jobs_exp = df_jobs_exp.sort_values(by='Applicant.ID')
df_jobs_exp.head()
# Out:
#        Applicant.ID select_pos_com_city  \
# 12370             2
# 12371             3
# 12372             6
# 12373             8
# 12374            11
#
#                                          Position.Name
# 12370                      volunteer writer uloop blog
# 12371                   market intern server prep cook
# 12372                                project assistant
# 12373  deli clerk server cashier food prep order taker
# 12374                                          cashier

# %% [markdown]
# Mesclando o cargo de interesse com o dataframe existente

# %%
df_jobs_exp_poi = df_jobs_exp.merge(df_poi, left_on='Applicant.ID', right_on='Applicant.ID', how='outer')
df_jobs_exp_poi = df_jobs_exp_poi.fillna(' ')
df_jobs_exp_poi = df_jobs_exp_poi.sort_values(by='Applicant.ID')
df_jobs_exp_poi.head()
# Out:
#    Applicant.ID select_pos_com_city  \
# 0             2
# 1             3
# 2             6
# 3             8
# 4            11
#
#                                      Position.Name Position.Of.Interest
# 0                      volunteer writer uloop blog
# 1                   market intern server prep cook
# 2                                project assistant
# 3  deli clerk server cashier food prep order taker
# 4                                          cashier

# %% [markdown]
# Combinando todas as colunas

# %%
df_jobs_exp_poi["text"] = df_jobs_exp_poi["select_pos_com_city"].map(str) + df_jobs_exp_poi["Position.Name"] +" "+ df_jobs_exp_poi["Position.Of.Interest"]

df_jobs_exp_poi.head()
# Out:
#    Applicant.ID select_pos_com_city  \
# 0             2
# 1             3
# 2             6
# 3             8
# 4            11
#
#                                      Position.Name Position.Of.Interest  \
# 0                      volunteer writer uloop blog
# 1                   market intern server prep cook
# 2                                project assistant
# 3  deli clerk server cashier food prep order taker
# 4                                          cashier
#
#                                                 text
# 0                      volunteer writer uloop blog
# 1                   market intern server prep cook
# 2                                project assistant
# 3   deli clerk server cashier food prep order tak...
# 4                                          cashier

# %% [markdown]
# Selecionando apenas as colunas "Applicant.ID" e "text"

# %%
df_final_person= df_jobs_exp_poi[['Applicant.ID','text']]
df_final_person.head()
# Out:
#    Applicant.ID                                               text
# 0             2                      volunteer writer uloop blog
# 1             3                   market intern server prep cook
# 2             6                                project assistant
# 3             8   deli clerk server cashier food prep order tak...
# 4            11                                          cashier

# %%
df_final_person.columns = ['Applicant_id','text']
df_final_person.head()
# Out:
#    Applicant_id                                               text
# 0             2                      volunteer writer uloop blog
# 1             3                   market intern server prep cook
# 2             6                                project assistant
# 3             8   deli clerk server cashier food prep order tak...
# 4            11                                          cashier

# %%
df_final_person['text'] = df_final_person['text'].apply(clean_txt)
df_final_person.head()
# Out:
# <ipython-input-37-d2edcdccb345>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_person['text'] = df_final_person['text'].apply(clean_txt)
#    Applicant_id                                             text
# 0             2                      volunteer writer uloop blog
# 1             3                   market intern server prep cook
# 2             6                                project assistant
# 3             8  deli clerk server cashier food prep order taker
# 4            11                                          cashier

# %% [markdown]
# Para testar o recomendador, selecionamos o usuário cujo ID é 326

# %%
u = 326
index = np.where(df_final_person['Applicant_id'] == u)[0][0]
user_q = df_final_person.iloc[[index]]
user_q
# Out:
#      Applicant_id            text
# 186           326  java developer

# %%
df_final_person['Applicant_id'].values
# Out:
# array([    2,     3,     6, ..., 14639, 14642, 14643])

# %% [markdown]
# ## Os sistemas de recomendação

# %% [markdown]
# #### TF-IDF

# %% [markdown]
# #### Count Vectorizer

# %% [markdown]
# ####  Similaridade do Cosseno
#
# É a métrica mais usada para calcular a semelhança entre textos. Matematizacente ela mede o cosseno do ângulo entre dois vetores projetados em um espaço multidimensional.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vemos aqui que o emprego de Engenheiro de Machine Learning e Cientista de Dados possuem uma similaridade, seu $ \theta $ é próximo de 0, o que fará seu cosseno ser próximo de 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Agora comparando dois empregos diferentes, como Cientista de Dados com Bartender, vamos uma baixa similaridade, devido ao seu $ \theta $ ser próximo de 90, o que fará seu cosseno ser próximo de 0.

# %% [markdown]
# Aqui calculamos a similaridade do cosse entre um vetor TF-IDF do texto do usuário e cada vetor TF-IDF da vaga de emprego.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

tfidf_jobid = tfidf_vectorizer.fit_transform((df_all['text']))
tfidf_jobid

# %%
from sklearn.metrics.pairwise import cosine_similarity
user_tfidf = tfidf_vectorizer.transform(user_q['text'])
cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf, x),tfidf_jobid)

# %%
output2 = list(cos_similarity_tfidf)

# %% [markdown]
# ###  Função para obter as recomendações principais por pontuação

# %% [markdown]
# - top será uma lista com as 10 vagas de emprego mais relevantes ao perfil do usuário.
# - scores serão as pontuações de similaridade de cosseno associadas às 10 vagas de emprego mais relevantes.

# %%
def get_recommendation(top, df_all, scores):
  recommendation = pd.DataFrame(columns = ['ApplicantID', 'JobID',  'title', 'score'])
  count = 0
  for i in top:
      recommendation.at[count, 'ApplicantID'] = u
      recommendation.at[count, 'JobID'] = df_all['Job.ID'][i]
      recommendation.at[count, 'title'] = df_all['Title'][i]
      recommendation.at[count, 'score'] =  scores[count]
      count += 1
  return recommendation

# %% [markdown]
# ##  As principais recomendações usando TF-IDF

# %% [markdown]
# Vamos criar uma lista com as 10 vagas mais relevantes para o usuário 326

# %%
top = sorted(range(len(output2)), key=lambda i: output2[i], reverse=True)[:10]
top

# %% [markdown]
# Obtemos o placar de similaridade de cada trabalho

# %%
list_scores = [output2[i][0][0] for i in top]
list_scores

# %% [markdown]
# Obtemos essas pontuações em ordem decrescente

# %%
get_recommendation(top,df_all, list_scores)

# %%
applicant_ids = np.array([2, 3, 6,  11, 326])

# %%
informacoes_candidatos = df_final_person[df_final_person['Applicant_id'].isin(applicant_ids)].drop_duplicates(subset='text')
informacoes_candidatos

# %%
# Inicialize a lista para armazenar os DataFrames
random_user_dfs1 = []

for u in applicant_ids:
    index = np.where(df_final_person['Applicant_id'] == u)[0][0]
    user_q = df_final_person.iloc[[index]]
    user_tfidf = tfidf_vectorizer.transform(user_q['text'])
    cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf, x), tfidf_jobid)
    output = list(cos_similarity_tfidf)
    top = sorted(range(len(output)), key=lambda i: output[i], reverse=True)[:10]
    list_scores = [output[i][0][0] for i in top]
    # Use a função get_recommendation para obter as recomendações
    recommendations_df = get_recommendation(top, df_all, list_scores)
    # Adicione o DataFrame à lista
    random_user_dfs1.append(recommendations_df)

# %%
# Salvar random_user_dfs
with open('random_user_dfs1.pkl', 'wb') as file:
    pickle.dump(random_user_dfs1, file)

# %%
# Caminho para o arquivo pickle no Google Drive
caminho_arquivo = '/content/drive/MyDrive/Dados_Empregos/random_user_dfs1.pkl'

# Carregue os dados do arquivo pickle
with open(caminho_arquivo, 'rb') as arquivo:
    random_user_dfs1 = pickle.load(arquivo)

# %%
random_user_dfs1[-1]
# Out:
#   ApplicantID   JobID                                              title  \
# 0         326  303112                         Java Developer @ TransHire
# 1         326  294684                          Java Developer @ Kavaliro
# 2         326  269922  Entry Level Java Developer / Jr. Java Develope...
# 3         326  141831  Lead Java/J2EE Developer - Contract to Hire @ ...
# 4         326  270171  Senior Java Developer - Contract to Hire - Gre...
# 5         326  305264        Sr. Java Developer @ Paladin Consulting Inc
# 6         326  309945     Java Software Engineer @ iTech Solutions, Inc.
# 7         326  245753                    Java Administrator @ ConsultNet
# 8         326  146640        Jr. Java Developer @ Paladin Consulting Inc
# 9         326  150882  Java Consultant - Mobile Apps Development @ Co...
#
#       score
# 0  0.749478
# 1  0.740886
# 2  0.737007
# 3  0.671667
# 4  0.645037
# 5  0.625532
# 6  0.592291
# 7  0.530231
# 8  0.510534
# 9  0.486789

# %% [markdown]
# ## As principais recomendações usando Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer()

count_jobid = count_vectorizer.fit_transform((df_all['text'])) #fitting and transforming the vector
count_jobid

# %%
from sklearn.metrics.pairwise import cosine_similarity
user_count = count_vectorizer.transform(user_q['text'])
cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x),count_jobid)
output3 = list(cos_similarity_countv)

# %%
output3 = list(cos_similarity_countv)

# %%
top = sorted(range(len(output3)), key=lambda i: output3[i], reverse=True)[:10]
list_scores = [output3[i][0][0] for i in top]
get_recommendation(top, df_all, list_scores)

# %%
# Inicializar a lista para armazenar os DataFrames
random_user_dfs2 = []

# Loop para 5 usuários aleatórios
for user_id in applicant_ids:
    index = np.where(df_final_person['Applicant_id'] == user_id)[0][0]
    user_q = df_final_person.iloc[[index]]
    user_count = count_vectorizer.transform(user_q['text'])

    cos_similarity_countv = map(lambda x: cosine_similarity(user_count, x), count_jobid)
    output = list(cos_similarity_countv)

    top = sorted(range(len(output)), key=lambda i: output[i][0][0], reverse=True)[:10]
    list_scores = [output[i][0][0] for i in top]

    # Aqui você precisará definir sua própria função get_recommendation
    user_df = get_recommendation(top, df_all, list_scores)

    # Adicionar o DataFrame do usuário à lista
    random_user_dfs2.append(user_df)

# %%
# Salvar random_user_dfs2
with open('random_user_dfs2.pkl', 'wb') as file:
    pickle.dump(random_user_dfs2, file)

# %%
# Caminho para o arquivo pickle no Google Drive
caminho_arquivo2 = '/content/drive/MyDrive/Dados_Empregos/random_user_dfs2.pkl'

# Carregue os dados do arquivo pickle
with open(caminho_arquivo2, 'rb') as arquivo:
    random_user_dfs2 = pickle.load(arquivo)

# %%
random_user_dfs2[-1]
# Out:
#   ApplicantID   JobID                                              title  \
# 0         326  303112                         Java Developer @ TransHire
# 1         326  294684                          Java Developer @ Kavaliro
# 2         326  269922  Entry Level Java Developer / Jr. Java Develope...
# 3         326  141831  Lead Java/J2EE Developer - Contract to Hire @ ...
# 4         326  270171  Senior Java Developer - Contract to Hire - Gre...
# 5         326  309945     Java Software Engineer @ iTech Solutions, Inc.
# 6         326  305264        Sr. Java Developer @ Paladin Consulting Inc
# 7         326  245753                    Java Administrator @ ConsultNet
# 8         326  150882  Java Consultant - Mobile Apps Development @ Co...
# 9         326  146640        Jr. Java Developer @ Paladin Consulting Inc
#
#       score
# 0  0.635001
# 1  0.600245
# 2  0.571726
# 3  0.496907
# 4  0.481757
# 5  0.454673
# 6  0.406017
# 7  0.378968
# 8  0.363216
# 9  0.323381

# %% [markdown]
# ## Resultados

# %% [markdown]
# - Java Developer
#
#   - TF-IDF
#     - Tem maiores scores, isso quer dizer que este algoritmo considera a frequência relativa das palavras
#   - CountVectorizer
#     - Menores scores

# %% [markdown]
# ## As principais recomendações usando com Spacy

# %%
import spacy

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2023-12-05 18:05:33.005736: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 18:05:33.005794: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 18:05:33.005827: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 18:05:34.297806: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !ls  /usr/local/lib/python3.6/dist-packages/en_core_web_lg
# Out:
# ls: cannot access '/usr/local/lib/python3.6/dist-packages/en_core_web_lg': No such file or directory

# %%
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# Transformar o texto do corpus em *spacy's documents*

# %%
# %%time
list_docs = []
for i in range(len(df_all)):
  doc = nlp("u'" + df_all['text'][i] + "'")
  list_docs.append((doc,i))
print(len(list_docs))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1040                 error_handler = proc.get_error_handler()
#    1041             try:
# -> 1042                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1043             except KeyError as e:
#    1044                 # This typically happens if a component is not initialized
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/tok2vec.py in predict(self, docs)
#     124             width = self.model.get_dim("nO")
#     125             return [self.model.ops.alloc((0, width)) for doc in docs]
# ...

# %%
import os
import pickle

# Criar o diretório 'artifacts' se não existir
if not os.path.exists('artifacts'):
    os.makedirs('artifacts')

# Salvar os arquivos
with open('artifacts/list_docs.pkl', 'wb') as f:
    pickle.dump(list_docs, f)

with open('artifacts/df_final_person.pkl', 'wb') as f:
    pickle.dump(df_final_person, f)

# %%
with open('artifacts/list_docs.pkl', 'rb') as file:
    list_docs = pickle.load(file)

# %%
import pickle
pickle.dump(list_docs,open('artifacts/list_docs.pkl','wb'))
pickle.dump(df_final_person,open('artifacts/df_final_person.pkl','wb'))

# %%
def calculateSimWithSpaCy(nlp, df, user_text, n=6):
    # Calculate similarity using spaCy
    list_sim =[]
    doc1 = nlp("u'" + user_text + "'")
    for i in df.index:
      try:
            doc2 = list_docs[i][0]
            score = doc1.similarity(doc2)
            list_sim.append((doc1, doc2, list_docs[i][1],score))
      except:
        continue

    return  list_sim

# %%
for user_index, user_text in user_q.text.items():
    df3 = calculateSimWithSpaCy(nlp, df_all, user_text, n=15)
    # Salvar os resultados com pickle
    with open(f'artifacts/user_{user_index}_similarity.pkl', 'wb') as f:
        pickle.dump(df3, f)

# %%
user_q.text[186]

# %%
# %%time
 df3 = calculateSimWithSpaCy(nlp, df_all, user_q.text[186], n=15)

# %%
df_recom_spacy = pd.DataFrame(df3).sort_values([3], ascending=False).head(10)

# %%
df_recom_spacy.reset_index(inplace=True)

# %%
index_spacy = df_recom_spacy[2]
list_scores = df_recom_spacy[3]

# %% [markdown]
# As principais recomendações usando Spacy

# %%
get_recommendation(index_spacy, df_all, list_scores)
