# %% [markdown]
# ___
#
# <a href='https://sites.google.com/fat.uerj.br/livia'> <img src='../figures/capa2.png' /></a>
# ___
#
# # Matplotlib Exercises
#
# Bem-vindo aos exercícios para revisar o matplotlib! Leve o seu tempo com isso, o Matplotlib pode ser complicado de entender no início. Esses são gráficos relativamente simples, mas podem ser difíceis se esta for sua primeira vez com o matplotlib, sinta-se à vontade para consultar as soluções à medida que avança.
#
# Além disso, não se preocupe se você achar a sintaxe do matplotlib frustrante, na verdade não a usaremos com tanta frequência ao longo do curso, mudaremos para o uso dos recursos de visualização incorporados do seaborn e do pandas. Mas, eles são construídos no matplotlib, e é por isso que ainda é importante obter exposição a ele!
#
# **NOTA: TODOS OS COMANDOS PARA PLOTAGEM DE UMA FIGURA DEVEM IR TODOS NA MESMA CÉLULA.SEPARÁ-LOS EM MÚLTIPLAS CÉLULAS PODE FAZER NADA APARECER.**
#
# # Exercícios
#
# Siga as instruções para recriar os gráficos usando esses dados:
#
# ## Dados

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **"Import matplotlib.pyplot as plt" e defina "%matplotlib inline" se estiver usando o notebook jupyter. Qual comando você usa se não estiver usando o notebook jupyter?**

# %% [markdown]
# ## Exercício 1
#
# Siga estas etapas:
# * Crie um objeto figure chamado fig usando plt.figure()
# * Use add_axes para adicionar um eixo à tela da figura em [0,0,1,1]. Chame esse novo eixo de `ax`.
# * Plote (x,y) nesses eixo e defina os rótulos e títulos para corresponder ao gráfico abaixo:

# %% [markdown]
# ## Exercício 2
# Crie um objeto de figura e coloque dois eixos nele, ax1 e ax2. Localizado em [0,0,1,1] e [0.2,0.5,.2,.2] respectivamente.

# %% [markdown]
# Agora plote (x,y) em ambos os eixos. E chame seu objeto de figura para mostrá-lo.

# %% [markdown]
# ## Exercício 3
#
# Crie o gráfico abaixo adicionando dois eixos a um objeto de figura em [0,0,1,1] e [0.2,0.5,.4,.4]

# %% [markdown]
# Agora use os arrays x, y e z para recriar o gráfico abaixo. Observe os limites x e y no gráfico inserido:

# %% [markdown]
# ## Exercício 4
#
# Use `plt.subplots(nrows=1, ncols=2)` para criar o gráfico abaixo.

# %% [markdown]
# Agora plote (x,y) e (x,z) nos eixos. Brinque com a largura de linha e o estilo

# %% [markdown]
# Veja se você pode redimensionar o gráfico adicionando o argumento figsize() em plt.subplots() copiando e colando seu código anterior.

# %% [markdown]
# # Excelente!
