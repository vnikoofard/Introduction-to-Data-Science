# %% [markdown]
# ___
#
# <a href='https://sites.google.com/fat.uerj.br/livia'> <img src='../../figures/capa2.png' /></a>
#
# ___
# # Seaborn Exercises
#
#
# Hora de praticar as novas habilidades adquiridos sobre o Seaborn! Tente recriar os gráficos abaixo (não se preocupe com esquemas de cores, apenas o gráfico em si.

# %% [markdown]
# ## Os dados
#
# Estaremos trabalhando com um famoso conjunto de dados titânico para esses exercícios. Mais tarde, na seção Machine Learning do curso, revisitaremos esses dados e os usaremos para prever as taxas de sobrevivência dos passageiros. Por enquanto, vamos nos concentrar apenas na visualização dos dados com seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %% [markdown]
# # Exercícios
#
# ** Recrie os gráficos abaixo usando o dataframe titânico. Existem muito poucas dicas, já que a maioria dos gráficos pode ser feita com apenas uma ou duas linhas de código e uma dica basicamente daria a solução. Preste muita atenção aos rótulos x e y para obter dicas.**
#
# **Observação! Para não perder a imagem da plotagem, certifique-se de não codificar na célula que está diretamente acima da plotagem, existe uma célula extra acima daquela que não irá sobrescrever essa plotagem!**

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
sns.distplot(titanic['fare'],bins=30,kde=False,color='red')

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
sns.countplot(x='sex',data=titanic)

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')

# %%
#CÓDIGO AQUI
# CUIDADO PARA NÃO SOBRESCREVER A CÉLULA ABAIXO
# ISSO REMOVERIA A IMAGEM DO PLOT DE EXERCÍCIOS!

# %%
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')

# %% [markdown]
# # Bom Trabalho!
#
# ### Por enquanto é isso! Veremos muito mais problemas práticos do Seaborn na seção de aprendizado de máquina!
